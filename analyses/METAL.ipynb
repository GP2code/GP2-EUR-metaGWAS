# %% [markdown]
# # METAL
#  - **Project:** GP2 Parkinson's disease meta-GWAS on European, Ashkenazi Jewish, Finnish, and Icelandic individuals
#  - **Versions:** R
#  - **Last Updated:** January 2025
#
# ### Notebook Overview
# Using METAL just to average effect allele frequencies
#
# ### CHANGELOG
# * 06-MAR-2025: Notebook cleaned
# * 31-JAN-2025: Notebook started

# %% [markdown]
# ```
# module load metal
# metal << EOT
#
# SCHEME STDERR
# AVERAGEFREQ ON
# MINMAXFREQ ON
# GENOMICCONTROL ON
#
# # === GP2 - EUR - CASE/CONTROL ===
# MARKER SNP
# ALLELE A1 A2
# FREQ EAF
# EFFECT BETA
# STDERR SE
# PVALUE P
# PROCESS {WORK_DIR}/GP2/POP_CONTROLS/GP2_EUR_CC_FOR_PLINK_MAF_POP_CONTROLS_freq.txt
#
# # === IPDGC - EUR - Courage UK - CASE/CONTROL ===
# MARKER SNP
# ALLELE A1 A2
# FREQ EAF
# EFFECT BETA
# STDERR SE
# PVALUE P
# PROCESS {WORK_DIR}/IPDGC/IPDGC_COURAGE_UK_EUR_CC_FOR_PLINK_MAF_freq.txt
#
# # === IPDGC - EUR - Dutch - CASE/CONTROL ===
# MARKER SNP
# ALLELE A1 A2
# FREQ EAF
# EFFECT BETA
# STDERR SE
# PVALUE P
# PROCESS {WORK_DIR}/IPDGC/IPDGC_DUTCH_EUR_CC_FOR_PLINK_MAF_freq.txt
#
# # === IPDGC - EUR - Germany - CASE/CONTROL ===
# MARKER SNP
# ALLELE A1 A2
# FREQ EAF
# EFFECT BETA
# STDERR SE
# PVALUE P
# PROCESS {WORK_DIR}/IPDGC/IPDGC_GERMANY_EUR_CC_FOR_PLINK_MAF_freq.txt
#
# # === IPDGC - EUR - McGill - CASE/CONTROL ===
# MARKER SNP
# ALLELE A1 A2
# FREQ EAF
# EFFECT BETA
# STDERR SE
# PVALUE P
# PROCESS {WORK_DIR}/IPDGC/IPDGC_MCGILL_EUR_CC_FOR_PLINK_MAF_freq.txt
#
# # === IPDGC - EUR - MF - CASE/CONTROL ===
# MARKER SNP
# ALLELE A1 A2
# FREQ EAF
# EFFECT BETA
# STDERR SE
# PVALUE P
# PROCESS {WORK_DIR}/IPDGC/IPDGC_MF_EUR_CC_FOR_PLINK_MAF_freq.txt
#
# # === IPDGC - EUR - NIA - CASE/CONTROL ===
# MARKER SNP
# ALLELE A1 A2
# FREQ EAF
# EFFECT BETA
# STDERR SE
# PVALUE P
# PROCESS {WORK_DIR}/IPDGC/IPDGC_NIA_EUR_CC_FOR_PLINK_MAF_freq.txt
#
# # === IPDGC - EUR - Oslo - CASE/CONTROL ===
# MARKER SNP
# ALLELE A1 A2
# FREQ EAF
# EFFECT BETA
# STDERR SE
# PVALUE P
# PROCESS {WORK_DIR}/IPDGC/IPDGC_OSLO_EUR_CC_FOR_PLINK_PD_freq.txt
#
# # === IPDGC - EUR - Shulman - CASE/CONTROL ===
# MARKER SNP
# ALLELE A1 A2
# FREQ EAF
# EFFECT BETA
# STDERR SE
# PVALUE P
# PROCESS {WORK_DIR}/IPDGC/IPDGC_SHULMAN_EUR_CC_FOR_PLINK_MAF_freq.txt
#
# # === IPDGC - EUR - Spain - CASE/CONTROL ===
# MARKER SNP
# ALLELE A1 A2
# FREQ EAF
# EFFECT BETA
# STDERR SE
# PVALUE P
# PROCESS {WORK_DIR}/IPDGC/IPDGC_SPAIN3_EUR_CC_NO_AGE_COVAR_FOR_PLINK_MAF_freq.txt
#
# # === IPDGC - EUR - Tubigen - CASE/CONTROL ===
# MARKER SNP
# ALLELE A1 A2
# FREQ EAF
# EFFECT BETA
# STDERR SE
# PVALUE P
# PROCESS {WORK_DIR}/IPDGC/IPDGC_TUBI_EUR_CC_FOR_PLINK_MAF_freq.txt
#
# # === IPDGC - EUR - UK GWAS - CASE/CONTROL ===
# MARKER SNP
# ALLELE A1 A2
# FREQ EAF
# EFFECT BETA
# STDERR SE
# PVALUE P
# PROCESS {WORK_DIR}/IPDGC/IPDGC_UK_GWAS_EUR_CC_FOR_PLINK_MAF_freq.txt
#
# # === FIGS - EUR - BATCH 1 thru 4 META ===
# MARKER MarkerName
# ALLELE Allele1 Allele2
# EFFECT Effect
# STDERR StdErr
# FREQ Freq1
# PVALUE P-value
# PROCESS {WORK_DIR}/METAS/FINAL_SETS/METAL_METAs/EUR_FIGS_METAL_4batches1.tbl
#
#
# # === UKBiobank - EUR ===
# MARKER SNP
# ALLELE A1 A2
# FREQ EAF
# EFFECT BETA
# STDERR SE
# PVALUE P
# PROCESS {WORK_DIR}/UKB/UKB_ALL/UKB_ALL_CC_FOR_PLINK_MAF_freq
#
# # === GP2 - AJ - CASE/CONTROL ===
# MARKER SNP
# ALLELE A1 A2
# FREQ EAF
# EFFECT BETA
# STDERR SE
# PVALUE P
# PROCESS {WORK_DIR}/GP2/UPDATED/GP2_AJ_CC_FOR_PLINK_MAF_update_freq.txt
#
# # === FIGS - AJ - CASE/CONTROL ===
# MARKER SNP
# ALLELE A1 A2
# FREQ EAF
# EFFECT BETA
# STDERR SE
# PVALUE P
# PROCESS {WORK_DIR}/FIGS/FIGS_AJ_CC_FOR_PLINK_MAF_freq.txt
#
# # === FinnGen - FIN ===
# MARKER SNP
# ALLELE A1 A2
# EFFECT BETA
# STDERR SE
# FREQ EAF
# PVALUE P
# PROCESS {WORK_DIR}/FINNGEN_R10_PD/finngen_R11_G6_PARKINSON_FOR_PLINK_MAF_freq
#
# # === IPDGC - FIN ===
# MARKER SNP
# ALLELE A1 A2
# EFFECT BETA
# STDERR SE
# FREQ EAF
# PVALUE P
# PROCESS {WORK_DIR}/IPDGC/IPDGC_FINLAND_FIN_CC_NO_AGE_FOR_PLINK_MAF_freq.txt
#
# # === deCODE - ICE ===
# MARKER SNP
# ALLELE A1 A2
# FREQ EAF
# EFFECT BETA
# STDERR SE
# PVALUE P
# PROCESS {WORK_DIR}/deCODE/deCODE_CC_FOR_PLINK_MAF_freq.txt
#
# # === MVP - EUR ===
# MARKER SNP
# ALLELE A1 A2
# EFFECT BETA
# STDERR SE
# FREQ EAF
# PVALUE P
# PROCESS {WORK_DIR}/MVP_CC_FOR_PLINK_MAF_freq.txt
#
# # === UKBiobank - EUR - Proxies!! ===
# MARKER SNP
# ALLELE A1 A2
# FREQ EAF
# EFFECT BETA
# STDERR SE
# PVALUE P
# PROCESS {WORK_DIR}/UKB/UKB_PROXY/UKB_PROXY_ADJUSTED_FOR_PLINK_freq.txt
#
# OUTFILE {WORK_DIR}/METAS/FINAL_SETS/METAL_METAs/EUR_ALL_METAL_cleanMVP_GC_JAN2025 .tbl
# ANALYZE HETEROGENEITY
#
# QUIT
# ```
